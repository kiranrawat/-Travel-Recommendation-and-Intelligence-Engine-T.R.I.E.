# %% [markdown]
# **Collaborative Filtering**
#
# Collaborative methods work with the interaction matrix that can also be called rating matrix in the rare case when users provide explicit rating of items. The task of machine learning is to learn a function that predicts utility of items to each user. Matrix is typically huge, very sparse and most of values are missing.
#
#
# Collaborative filtering methods are based on collecting and analyzing a large amount of information on user behaviors, activities or preferences and predicting what users will like based on their similarity to other users.
#
# The fundamental assumption behind collaborative filtering technique is that similar user preferences over the items could be exploited to recommend those items to a user who has not seen or used it before. In simpler terms, we assume that users who agreed in the past (purchased the same product or viewed the same movie) will agree in the future.
#
# **Aim is to find all these user and item dependencies in the Matrix.**
#
# Example:
#
# 24 = 8 * 3 <br>
#      ^   ^ <br>
#      |   | <br>
#      factors
#
# <b>Matrix Factorization</b>: Matrix Factorization finds two rectangular matrices with smaller dimensions to represent a big rating matrix (RM). These factors retain the dependencies and properties of the rating matrix. One matrix can be seen as the user matrix (UM) where rows represent users and columns are k latent factors. The other matrix is the item matrix (IM)where rows are k latent factors and columns represent items. Here k < number of items and k < number of users.

# %% [markdown]
# My Approach:
#
# - 1) Creating user-restaurant matrix
# - 2) Checking for sparsity
# - 3) Handling Sparsity using Matrix factorization where gradient descent will be appiled to lower the RMSE error and fill up the missing values in the matrix.
# - 4) Applying cosine similarity to calculate the similiarity socres for users.
# - 5) Applying Top K nearest neighbouros to find the top K recommended movies for the queries user id.

# %% [markdown]
# ## Importing necessary settings and modules

# %%
import pandas as pd

# %%
bus_reviews = pd.read_csv('output/business_review.csv',encoding = "ISO-8859-1",index_col=0)

# %%
bus_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  3bMgLXMLzm89C_0mkbIFOA  j9hC9EmCsS2S2ZtbsK-l0g  5Q4Gw1pyZnG8IlFNozxIlw
# 1  slhog3p6YaoVEej3USo2Iw  IJ1wbXUh_B5Yn6U1YWHy4g  5Q4Gw1pyZnG8IlFNozxIlw
# 2  noxz5btWWJjSpbUBmregVQ  _L-JKT5OahgimFlVOo708w  5Q4Gw1pyZnG8IlFNozxIlw
# 3  gmiMXHSb6loIDxopmOWHSA  x_I7IDsFeT4vVcEBZLqr7A  5Q4Gw1pyZnG8IlFNozxIlw
# 4  xfgHmu5n7cg-uNoU2C1lZg  ceLFSre4hrzkT5VpSlt2Lg  5Q4Gw1pyZnG8IlFNozxIlw
#
#    stars                          name  restuarant_stars  review_count  \
# 0      2  Native New Yorker Restaurant               3.0            22
# 1      1  Native New Yorker Restaurant               3.0            22
# 2      4  Native New Yorker Restaurant               3.0            22
# 3      5  Native New Yorker Restaurant               3.0            22
# 4      3  Native New Yorker Restaurant               3.0            22
#
#                                           attributes   categories     city
# 0  {'RestaurantsTakeOut': 'True', 'Ambience': "{'...  Restaurants  Gilbert
# 1  {'RestaurantsTakeOut': 'True', 'Ambience': "{'...  Restaurants  Gilbert
# 2  {'RestaurantsTakeOut': 'True', 'Ambience': "{'...  Restaurants  Gilbert
# 3  {'RestaurantsTakeOut': 'True', 'Ambience': "{'...  Restaurants  Gilbert
# 4  {'RestaurantsTakeOut': 'True', 'Ambience': "{'...  Restaurants  Gilbert

# %% [markdown]
# ## User based collaborative filtering

# %% [markdown]
# While doing exploratory analysis, we saw that Toronto has the highest number of resturant than other cities. So, we will be keeping the data for Toronto only.

# %%
bus_reviews = bus_reviews[bus_reviews['city'] == 'Toronto']

# %%
bus_reviews
# Out:
#                   review_id                 user_id             business_id  \
# 190  j99pOG3iUs85SagiXSaDVA  y6zJHfOZ1TQylruZOGWL5w  9DLBwCS4hu_xaiENCbYXbQ
# 191  NcLaiNYI8UTDnj2tbaY6_Q  DBHCFW3mSmmOEpONHVu1rQ  9DLBwCS4hu_xaiENCbYXbQ
# 192  8ENIH-hnN9RPOXk51DPzzQ  XN6InnJ-XfH4vRHNvHyYBw  9DLBwCS4hu_xaiENCbYXbQ
# 193  Cnvo0tIOH8G0zG9_uNsoyA  SptpVlrkT_hImZTyf6RItQ  9DLBwCS4hu_xaiENCbYXbQ
# 194  WOq0IEABXmwzMINp5lBhSA  0LiZRLlzGXI4ugV_p1Rrbg  9DLBwCS4hu_xaiENCbYXbQ
# 195  SFMpXt35e1HklPDhdITBeQ  zbyoPxKKqK1NHQ8_wUvqdQ  9DLBwCS4hu_xaiENCbYXbQ
# 196  bzVGArTcOvxOBpt3BGi9MA  hTsDirHtFsOeCC3TTypc-g  9DLBwCS4hu_xaiENCbYXbQ
# 197  wFt301O9q3pGR6zM17trzg  6J5N1B9-COnPtkMxNit3ug  9DLBwCS4hu_xaiENCbYXbQ
# 198  18pqmbBC9lvukqR9PWrWlw  accbcGY98ffb7H4FY1xrpA  9DLBwCS4hu_xaiENCbYXbQ
# 341  MXYgoQnZINRF1XYjPxAZmA  _Y5uwE-SfShOon4goDSRAA  Xxr4n8peOKw0csYEgVl0hA
# 342  NzgI2ZOqql2_IzqYvD_FHw  _xEw7D-qZ4DL2rOD5ZWPvg  Xxr4n8peOKw0csYEgVl0hA
# 343  tC3PuPAfNvZK5l6ZbIUN9w  d4xW-P-H2m5krflYfnMBdA  Xxr4n8peOKw0csYEgVl0hA
# 344  ndSUKJXzBS-iZNVjUvm3ag  _Y5uwE-SfShOon4goDSRAA  Xxr4n8peOKw0csYEgVl0hA
# 345  GWyA-raSNgBm8NZsMQqwZA  Y4IHIMqhXTYgk2NSBYZkqw  Xxr4n8peOKw0csYEgVl0hA
# 346  tiEG5UV7sW5_dUdrRnO2OQ  sNwdAjVugJ4CcM7fHOK4Zg  Xxr4n8peOKw0csYEgVl0hA
# 628  7HqiG2D_-t55wq-ZVD8Dow  tC5JCAJZ5NYadOtLCqw3UQ  YfAn2K4VSY-4sIo_CTRpjQ
# 629  G78ZE6KwDu5Qf2KHke-LcQ  StCSYeJ1I-G1LbdpW65kGQ  YfAn2K4VSY-4sIo_CTRpjQ
# 630  sTGcOlAcOWqMxH4huiVffQ  EvXY_Fa6X5_8Kch2zL4TdA  YfAn2K4VSY-4sIo_CTRpjQ
#
#      stars                                name  restuarant_stars  \
# 190      4  Chae Chester Fried Chicken Express               4.0
# 191      3  Chae Chester Fried Chicken Express               4.0
# 192      5  Chae Chester Fried Chicken Express               4.0
# 193      5  Chae Chester Fried Chicken Express               4.0
# 194      5  Chae Chester Fried Chicken Express               4.0
# 195      5  Chae Chester Fried Chicken Express               4.0
# 196      1  Chae Chester Fried Chicken Express               4.0
# 197      1  Chae Chester Fried Chicken Express               4.0
# 198      5  Chae Chester Fried Chicken Express               4.0
# 341      1                        Wing Machine               2.5
# 342      1                        Wing Machine               2.5
# 343      4                        Wing Machine               2.5
# 344      1                        Wing Machine               2.5
# 345      1                        Wing Machine               2.5
# 346      5                        Wing Machine               2.5
# 628      1                Ice Queen Restaurant               1.0
# 629      1                Ice Queen Restaurant               1.0
# 630      1                Ice Queen Restaurant               1.0
#
#      review_count                                         attributes  \
# 190             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 191             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 192             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 193             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 194             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 195             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 196             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 197             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 198             9  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 341             5  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 342             5  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 343             5  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 344             5  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 345             5  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 346             5  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 628             3  {'WiFi': "u'free'", 'RestaurantsDelivery': 'Tr...
# 629             3  {'WiFi': "u'free'", 'RestaurantsDelivery': 'Tr...
# 630             3  {'WiFi': "u'free'", 'RestaurantsDelivery': 'Tr...
#
#       categories     city
# 190  Restaurants  Toronto
# 191  Restaurants  Toronto
# 192  Restaurants  Toronto
# 193  Restaurants  Toronto
# 194  Restaurants  Toronto
# 195  Restaurants  Toronto
# 196  Restaurants  Toronto
# 197  Restaurants  Toronto
# 198  Restaurants  Toronto
# 341  Restaurants  Toronto
# 342  Restaurants  Toronto
# 343  Restaurants  Toronto
# 344  Restaurants  Toronto
# 345  Restaurants  Toronto
# 346  Restaurants  Toronto
# 628  Restaurants  Toronto
# 629  Restaurants  Toronto
# 630  Restaurants  Toronto
